# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load Dataset

# %%
data = pd.read_csv('DATASET DIABETES.csv')
data.head()
# Out:
#                              Target Genetic Markers Autoantibodies  \
# 0          Steroid-Induced Diabetes        Positive       Negative
# 1  Neonatal Diabetes Mellitus (NDM)        Positive       Negative
# 2                       Prediabetic        Positive       Positive
# 3                   Type 1 Diabetes        Negative       Positive
# 4                  Wolfram Syndrome        Negative       Negative
#
#   Family History Environmental Factors  Insulin Levels  Age  BMI  \
# 0             No               Present              40   44   38
# 1             No               Present              13    1   17
# 2            Yes               Present              27   36   24
# 3             No               Present               8    7   16
# 4            Yes               Present              17   10   17
#
#   Physical Activity Dietary Habits  ...  Pulmonary Function  \
# 0              High        Healthy  ...                  76
# ...

# %% [markdown]
# ## Basic Information about the Dataset
#
# - Menemukan Null Values
# - Menegtahui Tipe Data dari Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 34 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Target                         70000 non-null  object
#  1   Genetic Markers                70000 non-null  object
#  2   Autoantibodies                 70000 non-null  object
#  3   Family History                 70000 non-null  object
#  4   Environmental Factors          70000 non-null  object
#  5   Insulin Levels                 70000 non-null  int64
#  6   Age                            70000 non-null  int64
#  7   BMI                            70000 non-null  int64
#  8   Physical Activity              70000 non-null  object
#  9   Dietary Habits                 70000 non-null  object
#  10  Blood Pressure                 70000 non-null  int64
#  11  Cholesterol Levels             70000 non-null  int64
# ...

# %%
data.describe()
# Out:
#        Insulin Levels           Age           BMI  Blood Pressure  \
# count    70000.000000  70000.000000  70000.000000    70000.000000
# mean        21.607443     32.020700     24.782943      111.339543
# std         10.785852     21.043173      6.014236       19.945000
# min          5.000000      0.000000     12.000000       60.000000
# 25%         13.000000     14.000000     20.000000       99.000000
# 50%         19.000000     31.000000     25.000000      113.000000
# 75%         28.000000     49.000000     29.000000      125.000000
# max         49.000000     79.000000     39.000000      149.000000
#
#        Cholesterol Levels  Waist Circumference  Blood Glucose Levels  \
# count        70000.000000         70000.000000          70000.000000
# mean           194.867200            35.051657            160.701657
# std             44.532466             6.803461             48.165547
# min            100.000000            20.000000             80.000000
# ...

# %% [markdown]
# ## Cek Nilai Duplikat

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 69995    False
# 69996    False
# 69997    False
# 69998    False
# 69999    False
# Length: 70000, dtype: bool

# %%
data.duplicated().sum() #memastikan tidak ada nilai duplikat
# Out:
# 0

# %% [markdown]
# ## Cek Nilai Unik

# %%
unik = data.nunique()
unik
# Out:
# Target                             13
# Genetic Markers                     2
# Autoantibodies                      2
# Family History                      2
# Environmental Factors               2
# Insulin Levels                     45
# Age                                80
# BMI                                28
# Physical Activity                   3
# Dietary Habits                      2
# Blood Pressure                     90
# Cholesterol Levels                200
# Waist Circumference                35
# Blood Glucose Levels              220
# Ethnicity                           2
# Socioeconomic Factors               3
# Smoking Status                      2
# Alcohol Consumption                 3
# Glucose Tolerance Test              2
# History of PCOS                     2
# Previous Gestational Diabetes       2
# Pregnancy History                   2
# Weight Gain During Pregnancy       40
# Pancreatic Health                  90
# Pulmonary Function                 60
# ...

# %% [markdown]
# ## Visualisasi Nilai Unik

# %%
# Membuat bar plot horizontal untuk jumlah nilai unik di setiap kolom
plt.figure(figsize=(10,6))
sns.barplot(x=unik.values, y=unik.index, orient='h')

# Menambahkan judul dan label pada grafik
plt.title('Jumlah Nilai Unik di Setiap Kolom', fontsize=16)
plt.xlabel('Kolom', fontsize=10)
plt.ylabel('Jumlah Nilai Unik', fontsize=10)

# Menampilkan grafik
plt.show()

# %% [markdown]
# ## Filtering Data

# %% [markdown]
# - Dibawah ini adalah filter data anak usia 12 tahun ke bawah dengan diagnosis terkena penyakit diabetes. Beberapa variabel pendukung yang memperkuat hasil diagnosis yaitu Kadar Gula Darah yang lebih dari normal yaitu > 126, Penanda Genetik, Kadar Insulin yang tidak normal (rendah) yaitu kurang dari 15, Autoantibodi yang poaitive sering dikaitkan dengan Diabetes Autoimun, dan BMI anak yang kurang dari 18,5 berarti underweight atau lebih dari 30 berarti obesitas.

# %%
a = data[
    (data['Age'] <= 12) &
    (data['Blood Glucose Levels'] > 126) &
    (data['Genetic Markers'] == 'Positive') &
    (data['Insulin Levels'] < 15) &
    (data['Autoantibodies'] == 'Positive') &
    ((data['BMI'] < 18.5) | (data['BMI'] > 30))
]
a
# Out:
#                                  Target Genetic Markers Autoantibodies  \
# 95     Neonatal Diabetes Mellitus (NDM)        Positive       Positive
# 116           Wolcott-Rallison Syndrome        Positive       Positive
# 215    Neonatal Diabetes Mellitus (NDM)        Positive       Positive
# 226    Neonatal Diabetes Mellitus (NDM)        Positive       Positive
# 277                     Type 1 Diabetes        Positive       Positive
# ...                                 ...             ...            ...
# 69813         Wolcott-Rallison Syndrome        Positive       Positive
# 69831         Wolcott-Rallison Syndrome        Positive       Positive
# 69896         Wolcott-Rallison Syndrome        Positive       Positive
# 69900  Neonatal Diabetes Mellitus (NDM)        Positive       Positive
# 69928         Wolcott-Rallison Syndrome        Positive       Positive
#
#       Family History Environmental Factors  Insulin Levels  Age  BMI  \
# ...

# %% [markdown]
# ## Membuat Box Plot Distribusi Kadar Glukosa Darah pada Anak-Anak Sesuai Kriteria pada Filtering Data

# %%
#Membuat Plot
plt.figure(figsize=(12, 6)) #Ukuran Figure
plt.boxplot([a['Blood Glucose Levels'][a['Genetic Markers'] == 'Positive']],
             labels=['Positive'])

# Judul dan Label Plot
plt.title('Boxplot of Blood Glucose Levels for Filtered Data')
plt.xlabel('Genetic Markers')
plt.ylabel('Blood Glucose Levels')

# Menampilkan plot
plt.show()

# %% [markdown]
# ## Korelasi

# %%
# Menghitung matriks korelasi
korelasi = a.corr()
print(korelasi)
# Out:
#                               Insulin Levels       Age       BMI  \
# Insulin Levels                      1.000000  0.114529  0.021536
# Age                                 0.114529  1.000000  0.337740
# BMI                                 0.021536  0.337740  1.000000
# Blood Pressure                      0.068939  0.739063  0.325837
# Cholesterol Levels                 -0.050201 -0.106868 -0.037540
# Waist Circumference                 0.053942  0.553664  0.262269
# Blood Glucose Levels                0.153954  0.522271  0.210925
# Weight Gain During Pregnancy       -0.019316 -0.090765 -0.035600
# Pancreatic Health                   0.014445  0.176375  0.069578
# Pulmonary Function                 -0.067312 -0.281140 -0.085459
# Neurological Assessments           -0.020441 -0.005050  0.026226
# Digestive Enzyme Levels             0.028889  0.196969  0.074110
# Birth Weight                       -0.047100  0.066626  0.036647
#
# ...

# %%
# Mengatur ukuran figure
plt.figure(figsize=(12, 10))

# Membuat heatmap
sns.heatmap(korelasi, annot=True, fmt=".2f", cmap='coolwarm', square=True, cbar=True)

# Menambahkan judul
plt.title('Korelasi antara Variabel dalam Dataset')

# Menampilkan plot
plt.show()
